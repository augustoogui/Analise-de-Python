# %% [markdown]
# <a href="https://colab.research.google.com/github/augustoogui/Analise-de-Python/blob/main/AnalisePython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python One

# %% [markdown]
# # Operadores

# %%
a, b = 5, 3

# %%
a + b
# Out:
# 8

# %%
a -b
# Out:
# 2

# %%
a*b
# Out:
# 15

# %% [markdown]
# ## Operadores Lógicos

# %%
a <b
# Out:
# False

# %%
a >b
# Out:
# True

# %%
a==b
# Out:
# False

# %% [markdown]
# # String

# %%
comida = "Macarrão de Quiejo"

# %%
comida.lower()
# Out:
# 'macarrão de quiejo'

# %%
comida
# Out:
# 'Macarrão de Quiejo'

# %%
comida.upper()
# Out:
# 'MACARRÃO DE QUIEJO'

# %%
comida.capitalize()
# Out:
# 'Macarrão de quiejo'

# %%
comida*3
# Out:
# 'Macarrão de QuiejoMacarrão de QuiejoMacarrão de Quiejo'

# %%
comida+comida
# Out:
# 'Macarrão de QuiejoMacarrão de Quiejo'

# %%
len(comida)
# Out:
# 18

# %% [markdown]
# # Variaveis

# %%
import keyword
print (keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Atribuição Multipla
a, b,c, d = 'OI' , 3.14, 26, False

# %%
a
# Out:
# 'OI'

# %%
a = float(c)

# %%
a = int(a)

# %%
type(a)
# Out:
# int

# %% [markdown]
# # Indice e o fatiamento

# %%
salada = "alface com tomate"

# %%
salada[0]
# Out:
# 'a'

# %%
salada [9]
# Out:
# 'm'

# %%
salada [0:9]
# Out:
# 'alface co'

# %%
salada [6:]
# Out:
# ' com tomate'

# %%
salada [6::2]
# Out:
# ' o oae'

# %% [markdown]
# # LISTAS

# %%
lista_compra = ["Alface", 'mercedes', 70, 3.14]

# %%
type(lista_compra)
# Out:
# list

# %%
lista_compra[3]
# Out:
# 3.14

# %% [markdown]
# lista_compra

# %%
lista_compra.append("churrasco")

# %%
lista_compra.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
lista_compra = ["Alface", 'tomate', "pão", 'hamburgeuer']

# %%
lista_compra = " e ".join(lista_compra)

# %% [markdown]
# Set - Conjuntos

# %%
lista = [1,1,2,3,4,3,2,5,4,6,7,8,9]

# %%
conjunto = set(lista)

# %%
print (conjunto)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
type(conjunto)
# Out:
# set

# %% [markdown]
# # Dicionário

# %%
cadastro = {"nome": "Guilherme", 'idade':26, 'fruta': 'maca', "cor": "laranja", 'musica': 'rock'}

# %%
cadastro['nome']
# Out:
# 'Guilherme'

# %%
tupla1= ("Nome", 'Guilherme')
tupla2 = ('idade', 26)
tupla3 = ('cor', 'larnaja')
tupla4 = ("fruta", 'jabitucaba')
tupla5 = ('musica', 'rock')

# %%
lista_tuplas = [tupla1, tupla2, tupla3, tupla4, tupla5]

# %%
cadastro = dict(lista_tuplas)

# %%
cadastro
# Out:
# {'Nome': 'Guilherme',
#  'idade': 26,
#  'cor': 'larnaja',
#  'fruta': 'jabitucaba',
#  'musica': 'rock'}

# %%
cadastro["fruta"] = 'manga'

# %%
del cadastro['musica']

# %%
cadastro
# Out:
# {'Nome': 'Guilherme', 'idade': 26, 'cor': 'larnaja', 'fruta': 'manga'}

# %%
cadastro.update({"nome": "Guido", 'idade':26, 'fruto': 'maca', "cor": "laranja", 'musica': 'rock'})

# %%
cadastro
# Out:
# {'Nome': 'Guilherme',
#  'idade': 26,
#  'cor': 'laranja',
#  'fruta': 'manga',
#  'nome': 'Guido',
#  'fruto': 'maca',
#  'musica': 'rock'}

# %% [markdown]
# # Leitura e Escrita

# %%
input("Escreva seu nome")

# %%
print(nome)
# Out:
# 26

# %%
saudacao = f"Olá, {nome}!"

# %%
saudacao
# Out:
# 'Olá, 26!'

# %% [markdown]
# Loop

# %%
## for

# %%
frutas = ["Abacaxi", "Banana", "Uva", "Abacate"]

# %%
for fruta in frutas:
  if fruta.startswith('A'):
    print(fruta)
# Out:
# Abacaxi
# Abacate

# %%
lista = [1,2,3,4,5]
soma = 0
for numero in lista:
  soma = soma+numero

  print(soma)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
multiplos = range(1,11)

# %%
x = int(input("Selecione um número "))
for i in multiplos:
  print(f"{i} X {x} = {i* x}")
# Out:
# Selecione um número 5
# 1 X 5 = 5
# 2 X 5 = 10
# 3 X 5 = 15
# 4 X 5 = 20
# 5 X 5 = 25
# 6 X 5 = 30
# 7 X 5 = 35
# 8 X 5 = 40
# 9 X 5 = 45
# 10 X 5 = 50
